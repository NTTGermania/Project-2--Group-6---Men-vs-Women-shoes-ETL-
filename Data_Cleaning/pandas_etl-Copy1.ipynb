# %%
import pandas as pd
from sqlalchemy import create_engine, inspect

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
man_shoe_file = "../Resources/7003_1.csv"
man_shoe_df = pd.read_csv(man_shoe_file)
man_shoe_df.head()
# Out:
# /var/folders/_3/fpx1kffx6n90zjt7rjys0h6r0000gn/T/ipykernel_16119/3663407765.py:2: DtypeWarning: Columns (25,36,39,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   man_shoe_df = pd.read_csv(man_shoe_file)
#                      id asins      brand  \
# 0  AVpfBXx21cnluZ0-cKxs   NaN       Zoot
# 1  AVpfBXx21cnluZ0-cKxs   NaN       Zoot
# 2  AVpfBXx21cnluZ0-cKxs   NaN       Zoot
# 3  AVpfBXx21cnluZ0-cKxs   NaN       Zoot
# 4  AVpfEqFRLJeJML431x7w   NaN  Wild Pair
#
#                                        categories           colors  count  \
# 0  Shoes,Clothing,Women's Shoes,All Women's Shoes  Blue,Multicolor    NaN
# 1  Shoes,Clothing,Women's Shoes,All Women's Shoes  Blue,Multicolor    NaN
# 2  Shoes,Clothing,Women's Shoes,All Women's Shoes  Blue,Multicolor    NaN
# 3  Shoes,Clothing,Women's Shoes,All Women's Shoes  Blue,Multicolor    NaN
# 4  Shoes,Women's Shoes,Clothing,All Women's Shoes            Brown    NaN
#
# ...

# %%
man_shoe_df["categories"]
# Out:
# 0                                                      Men
# 1                                                      Men
# 2                                                      Men
# 3                                                      Men
# 4           Shoes,Women's Shoes,Clothing,All Women's Shoes
#                                ...
# 19040    Watches,Clothing, Shoes & Jewelry,Women,Wrist ...
# 19041                                                  Men
# 19042                                                  Men
# 19043                                                  Men
# 19044                                                  Men
# Name: categories, Length: 19045, dtype: object

# %%
man_shoe_df['categories'] =man_shoe_df['categories'].replace(["Shoes,Clothing,Women's Shoes,All Women's Shoes"],"Men")
man_shoe_df['categories'] =man_shoe_df['categories'].replace(["Shoes,Women's Shoes,Clothing,All Women's Shoes"],"Men")
man_shoe_df['categories'] =man_shoe_df['categories'].replace(["Clothing,Shoes,Men's Shoes,All Men's Shoes"],"Men")

# %%
man_shoe_df.head(20)
# Out:
#                       id asins            brand  \
# 0   AVpfBXx21cnluZ0-cKxs   NaN             Zoot
# 1   AVpfBXx21cnluZ0-cKxs   NaN             Zoot
# 2   AVpfBXx21cnluZ0-cKxs   NaN             Zoot
# 3   AVpfBXx21cnluZ0-cKxs   NaN             Zoot
# 4   AVpfEqFRLJeJML431x7w   NaN        Wild Pair
# 5   AVpfEqFRLJeJML431x7w   NaN        Wild Pair
# 6   AVpfEqFRLJeJML431x7w   NaN        Wild Pair
# 7   AVpfFCfi1cnluZ0-dcCZ   NaN    Sutton Studio
# 8   AVpfFCfi1cnluZ0-dcCZ   NaN    Sutton Studio
# 9   AVpfBZCAilAPnD_xTN_K   NaN      LaLeela.com
# 10  AVpfBZCAilAPnD_xTN_K   NaN      LaLeela.com
# 11  AVpfHscY1cnluZ0-eVb6   NaN           Reebok
# 12  AVpfHscY1cnluZ0-eVb6   NaN           Reebok
# 13  AVpfHscY1cnluZ0-eVb6   NaN           Reebok
# 14  AVpfHscY1cnluZ0-eVb6   NaN           Reebok
# 15  AVpfHscY1cnluZ0-eVb6   NaN           Reebok
# 16  AVpfHscY1cnluZ0-eVb6   NaN           Reebok
# 17  AVpfHscY1cnluZ0-eVb6   NaN           Reebok
# ...

# %%
man_shoe_df.replace("Shoes,Clothing,Women's Shoes,All Women's Shoes", "Men")
man_shoe_df
# Out:
#                          id                  asins      brand  \
# 0      AVpfBXx21cnluZ0-cKxs                    NaN       Zoot
# 1      AVpfBXx21cnluZ0-cKxs                    NaN       Zoot
# 2      AVpfBXx21cnluZ0-cKxs                    NaN       Zoot
# 3      AVpfBXx21cnluZ0-cKxs                    NaN       Zoot
# 4      AVpfEqFRLJeJML431x7w                    NaN  Wild Pair
# ...                     ...                    ...        ...
# 19040  AVpe6e3f1cnluZ0-Zsk7  B00THZJCTY,B01A9EKQS2      NIXON
# 19041  AVpfXLGG1cnluZ0-jY7B                    NaN     Tundra
# 19042  AVpfXLGG1cnluZ0-jY7B                    NaN     Tundra
# 19043  AVpfXLGG1cnluZ0-jY7B                    NaN     Tundra
# 19044  AVpfXLGG1cnluZ0-jY7B                    NaN     Tundra
#
#                                               categories           colors  \
# 0         Shoes,Clothing,Women's Shoes,All Women's Shoes  Blue,Multicolor
# ...

# %%
clean_men_df = men_shoe_df.at[2:19388,'categories'] =  "Men"
clean_men_df
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 clean_men_df = men_shoe_df.at[2:19388,'categories'] =  "Men"
#       2 clean_men_df
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/indexing.py:2281, in _AtIndexer.__setitem__(self, key, value)
#    2278     self.obj.loc[key] = value
#    2279     return
# -> 2281 return super().__setitem__(key, value)
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/indexing.py:2236, in _ScalarAccessIndexer.__setitem__(self, key, value)
#    2233 if len(key) != self.ndim:
#    2234     raise ValueError("Not enough indexers for scalar access (setting)!")
# -> 2236 self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# ...

# %%
women_shoe_file = "../Resources/7004_1.csv"
women_shoe_df = pd.read_csv(women_shoe_file)
women_shoe_df.head()
# Out:
# /var/folders/_3/fpx1kffx6n90zjt7rjys0h6r0000gn/T/ipykernel_16119/2078812204.py:2: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   women_shoe_df = pd.read_csv(women_shoe_file)
#                      id asins                brand  \
# 0  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 1  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 2  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 3  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 4  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
#
#                                    categories colors  count  \
# 0  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 1  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 2  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 3  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 4  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
#
#               dateadded           dateupdated  \
# ...

# %% [markdown]
# ### Transform men's shoes DataFrame

# %%
# Create a filtered dataframe from specific columns
men_shoe_cols = ["id", "brand", "categories", "prices_amountmin", "prices_amountmax"]
men_shoe_transformed = clean_men_df[men_shoe_cols].copy()

# Rename the column headers
men_shoe_transformed = men_shoe_transformed.rename(columns={"prices_amountmin": "($)prices_min",
                                                          "prices_amountmax": "($)prices_max"})

# Clean the data by dropping duplicates and setting the index
men_shoe_transformed.drop_duplicates("id", inplace=True)
men_shoe_transformed.set_index("id", inplace=True)

men_shoe_transformed.head()
# Out:
#                               brand  \
# id
# AVpfBXx21cnluZ0-cKxs           Zoot
# AVpfEqFRLJeJML431x7w      Wild Pair
# AVpfFCfi1cnluZ0-dcCZ  Sutton Studio
# AVpfBZCAilAPnD_xTN_K    LaLeela.com
# AVpfHscY1cnluZ0-eVb6         Reebok
#
#                                                              categories  \
# id
# AVpfBXx21cnluZ0-cKxs     Shoes,Clothing,Women's Shoes,All Women's Shoes
# AVpfEqFRLJeJML431x7w     Shoes,Women's Shoes,Clothing,All Women's Shoes
# AVpfFCfi1cnluZ0-dcCZ  Women's Suits & Sets,Women's Clothing,All Wome...
# AVpfBZCAilAPnD_xTN_K  Women's Clothing,All Women's Clothing,Clothing...
# AVpfHscY1cnluZ0-eVb6  Shoes,Clothing,Women's Shoes,All Women's Shoes...
#
#                      ($)prices_min ($)prices_max
# id
# AVpfBXx21cnluZ0-cKxs         71.99         71.99
# AVpfEqFRLJeJML431x7w         26.98         26.98
# AVpfFCfi1cnluZ0-dcCZ           318           318
# AVpfBZCAilAPnD_xTN_K         27.98         27.98
# ...

# %% [markdown]
# # Transform women's shoes DataFrame

# %%
# Create a filtered dataframe from specific columns
women_shoe_cols = ["id", "brand", "categories", "prices_amountmin", "prices_amountmax"]
women_shoe_transformed = women_shoe_df[women_shoe_cols].copy()

# Rename the column headers
women_shoe_transformed = women_shoe_transformed.rename(columns={"prices_amountmin": "($)prices_min",
                                                          "prices_amountmax": "($)prices_max"})

# Clean the data by dropping duplicates and setting the index
women_shoe_transformed.drop_duplicates("id", inplace=True)
women_shoe_transformed.set_index("id", inplace=True)

women_shoe_transformed.head()
# Out:
#                                     brand  \
# id
# AVpfHrJ6ilAPnD_xVXOI                Josmo
# AVpfHsWP1cnluZ0-eVZ7  SERVUS BY HONEYWELL
# AVpfAwehilAPnD_xS_eB               NATIVE
# AVpfFCHeilAPnD_xUeS0        MAUI AND SONS
# AVpfHssKilAPnD_xVXu5               Hao-bo
#
#                                                              categories  \
# id
# AVpfHrJ6ilAPnD_xVXOI         Clothing,Shoes,Men's Shoes,All Men's Shoes
# AVpfHsWP1cnluZ0-eVZ7         All Men's Shoes,Shoes,Men's Shoes,Clothing
# AVpfAwehilAPnD_xS_eB      Men's Casual Shoes,Shoes,Men's Shoes,Clothing
# AVpfFCHeilAPnD_xUeS0         All Men's Shoes,Shoes,Men's Shoes,Clothing
# AVpfHssKilAPnD_xVXu5  Clothing, Shoes, Accessories,Bags, Briefcases,...
#
#                      ($)prices_min ($)prices_max
# id
# AVpfHrJ6ilAPnD_xVXOI         39.89         39.89
# AVpfHsWP1cnluZ0-eVZ7         40.02         40.02
# AVpfAwehilAPnD_xS_eB         45.00         45.00
# AVpfFCHeilAPnD_xUeS0          9.99          9.99
# ...

# %% [markdown]
# ### changing value of categories from  men's shoes DataFrame

# %%
clean_men_df = men_shoe_transformed.loc[:,'categories'] =  "Men"

# %%
clean_men_df
# Out:
# 'Men'

# %%
#Combining Languages that had names masked together as well as separated

# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing,Shoes,Men's Shoes,All Men's Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Casual Shoes,Shoes,Men's Shoes,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes, Accessories,Bags, Briefcases,Men's Accessories"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Halloween Costumes,Adult Halloween Costumes,Clothing, Shoes & Accessories,Halloween,Men,Costumes, Reenactment, Theater,All Costumes,Costumes,Party & Occasions"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Clothing,Underwear"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Clothing,Shorts,Sporting Goods,Boxing, Martial Arts & MMA"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes, Accessories,Men's Sunglasses"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "All Men's Clothing,Men's Clothing,Men's Outerwear,Clothing, Shoes & Jewelry,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Sporting Goods,Team Sports,Basketball,Clothing, Shoes & Accessories,Shoes,Men"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Accessories,Backpacks, Bags & Briefcases"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Athletic,Men,Shoes,Shoes & Handbags"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Boots,Shoes,Men's Shoes,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "All Men's Shoes,Shoes,Men's Shoes,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men,Shoes,Oxfords & Derby Shoes,Wingtip"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing,Jewellery,Cufflinks & Shirt Accessories,Tie Clips,Clothing, Shoes & Jewelry,Men,Jewelry,Religious,Tie Pins & Clips,Ties & Cummerbunds,Accessories,Bags & Accessories"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Sporting Goods,Team Sports,Soccer,Clothing, Shoes & Accessories,Shoes & Cleats,Men"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Shoes,Clothing, Shoes & Jewelry,Men,Shoes & Handbags"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Shoes,Athletic"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing,Shoes,Men's Shoes,Men's Casual Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Running Shoes,Running Shoes,Running Gear,Fitness & Exercise Equipment,Men's Shoes,Athletic & Running Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Team Sports,Men,Soccer,Shoes & Cleats,Sporting Goods"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Luggage & Bags,Juniors Messenger Bags & Backpacks,Home,Backpacks & Bags,Travel Bags,Bags & Accessories,Men's Bags,Juniors Accessories,Office Supplies,School Supplies,Backpacks,Men's Accessories,Clothing, Shoes & Jewelry"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Shoes,Boots,See more Thorogood Mens Classics Brown Leather EH Safet..."
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "SLP,Finish Line Athletic Shoes,Men,Nike Sneakers,Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Workwear & Uniforms,Men's Workwear & Uniforms,Men's Coveralls,Clothing, Shoes & Jewelry,Clothing,Men's Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing,Shoes,Men's Shoes,Men's Dress Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Dress Shoes,Shoes,Men's Shoes,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes, Accessories,Men's Sunglasses,Women's Sunglasses"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Shoes,Athletic,Men"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Work Gloves,Power Tools,Safety Apparel,Women's Workwear & Uniforms,Safety & Shop Gear,Workwear & Uniforms,Hand Tools,Clothing,Tools,Men's Clothing,Office Supplies,Women's Clothing,Women's Work Gloves,Gloves,Women's Workwear Accessories,Clothing, Shoes & Jewelry,Men's Workwear & Uniforms,Men's Workwear Accessories,Office Safety & Security"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Shoes,Clothing, Shoes & Jewelry,Men,Athletic,Team Sports,Basketball"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Accessories,Backpacks, Bags & Briefcases"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "All Men's Clothing,Men's Clothing,Clothing, Shoes & Jewelry,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "All Men's Clothing,Men's Clothing,Men's Socks,Clothing, Shoes & Jewelry,Men's Socks & Underwear,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Shoes,Casual"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men,Shoes,Finish Line Athletic Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Home Improvement,Work Safety Clothing and Equipment,Men's Work & Safety Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men,Shoes,Boat Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Sunglasses,Clothing, Shoes, Accessories,Walmart Vision Centers,Health,Men's Sunglasses"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Home Improvement,Men's Work & Safety Shoes,Work Safety Clothing and Equipment"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "All Men's Clothing,Men's Clothing,Clothing, Shoes & Jewelry,Men's Jeans,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Accessories,Sunglasses & Fashion Eyewear,Sunglasses,Women's Accessories"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Activewear,All Men's Clothing,Men's Clothing,Clothing, Shoes & Jewelry,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Shoes,Boots"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Accessories,Hats"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Boots,Shoes,Clothing, Shoes & Jewelry,Men's Shoes,Men's Work Shoes & Boots"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Jewelry,Fashion Jewelry,Fashion Rings,Clothing, Shoes & Jewelry,Men's Jewelry,Men's Rings"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Jewelry,Clothing,Men's Clothing,Men's Socks & Underwear,Men's Socks,All Men's Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Loafers & Slip-Ons,Men,Shoes,Clothing, Shoes & Jewelry"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Jewelry,Men's Rings,Rings,Clothing, Shoes & Jewelry,Jewelry"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men%27s Jewelry,Anniversary Jewelry,Clothing, Shoes & Jewelry,Fashion Bracelets & Charms,Bracelets,Jewelry,Men%27s Bracelets,Fashion Jewelry,Men%27s Anniversary Jewelry"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Athletic & Running Shoes,Men's Shoes,Cross-Training Shoes"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Clothing,Athletic Apparel"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Sleepwear,All Men's Clothing,Home,Men's Clothing,Clothing, Shoes & Jewelry,Bath Robes & Wraps,Personal Care,Bath,Clothing,Bed & Bath,Bath Towels & Rugs"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Football,Clothing, Shoes & Accessories,Team Sports,Men,Shoes & Cleats,Sporting Goods"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Clothing, Shoes & Accessories,Men's Shoes,Athletic,See more Nike Air Jordan Future Low Cool Grey Black Whi..."
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "All Men's Shoes,Men's Casual Shoes,Shoes,Men's Shoes,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == "Men's Slippers,Shoes,Men's Shoes,Clothing"
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""
# men_shoe_transformed.loc[men_shoe_transformed["categories"] == "Men's"] == ""

# %%
complete_primary_home_language.loc[complete_primary_home_language["Language Name"] == "ADANGME", "Language Name"] = "ADANGME/AKAN/DAGOMBA/DAGBANE/FANTE/FANTI/GA/TWI/EWE/GURMA"

# %% [markdown]
# ### changing value of categories from  women's shoes DataFrame

# %% [markdown]
# ### Create database connection

# %%
protocol = 'postgresql'
username = 'postgres'
password = '<password>'
host = 'localhost'
port = 5432
database_name = 'customer_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
# Confirm tables
inspector = inspect(engine)
inspector.get_table_names()

# %% [markdown]
# ### Load DataFrames into database

# %%
premise_transformed.to_sql(name='premise', con=engine, if_exists='append', index=True)

# %%
county_transformed.to_sql(name='county', con=engine, if_exists='append', index=True)
